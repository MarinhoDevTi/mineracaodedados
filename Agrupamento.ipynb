# %%
from sklearn.datasets import make_blobs
import numpy as np 
import matplotlib.pyplot as plt 

c = [(-5,-5), (0,0), (3,4), (10,-5)]

n = 400

data = make_blobs(n_samples = n, n_features = 2, centers = c, cluster_std = 2,
                 random_state=42)

X = data[0]

labels = data[1]


plt.figure(figsize=(8,6))
plt.scatter(X[:,0], X[:,1], c=labels, cmap ='viridis', s = 50, alpha = 0.9)

plt.xlim(-15,20)
plt.ylim(-15,15)
plt.show()

# %%
from sklearn.cluster import KMeans

k = 4

Kmeans = KMeans(n_clusters=k)

Kmeans.fit(x)
y_km = Kmeans.fit_predict(x)

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)

plt.scatter(X[:,0], X[:,1], c= y_km, cmap='viridis', s=50)
plt.xlim(-15,20)
plt.ylim(-15,15)
plt.title("k-Means")
centers = Kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='red', s=100, alpha = 0.9)
plt.subplot(1,2,2)
plt.scatter(X[:,0], X[:,1], c=labels, cmap = 'viridis', s=50)
plt.xlim(-15,20)
plt.ylim(-15,15)
plt.title('Dados originais')
plt.show()
# Out:
# /home/marinhotech/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/marinhotech/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
WCSS = []

K = range(1,10)

for km in K:
    kmeans = Kmeans(n_clusters = km)
    Kmeans.fit(X)
    WCSS.append(kmeans.inertia_)
    
    
plt.figure(figsize=(8,6))
plt.plot(k, WCSS, '-bo')
plt.xlabel('k')
plt.ylabel('WCSS')
plt.title('O método Eklbeow mostra o valor otimo de k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 K = range(1,10)
#       5 for km in K:
# ----> 6     kmeans = Kmeans(n_clusters = km)
#       7     Kmeans.fit(X)
#       8     WCSS.append(kmeans.inertia_)
#
# TypeError: 'KMeans' object is not callable

# %%
from sklearn import cluster, datasets 


plt.figure(figsize=(15,5))

n_samples = 1000

data = datasets.make_moons(n_samples = n, noise = 0.05)

X=data[0]

labels = data[1]

plt.subplot(1,2,1)
plt.scatter(X[:,0], X[:,1], c=data[1], cmap='viridis', s=50, alpha=0.7)
plt.show()

# %%
k = 2 

clustering = cluster.AgglomerativeClustering(n_clusters=k, linkage='ward')
y_hr = clustering.fit_predict(x)
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.scatter(X[:,0], X[:,1], c=y_hr, cmap ='viridis', s=50)
plt.title("Aggloremative Clustering: Ward")

plt.subplot(1,2,2)
plt.scatter(X[:,0], X[:,1], c=y_hr, cmap ='viridis', s=50)
plt.title("Aggloremative Clustering: Ward")
# Out:
# Text(0.5, 1.0, 'Aggloremative Clustering: Ward')

# %%
clustering = cluster.AgglomerativeClustering(n_clusters=k, linkage='ward')
y_hr = clustering.fit_predict(x)
plt.figure(figsize=(15,5))
plt.subplot(2,2,1)
plt.scatter(X[:,0], X[:,1], c=y_hr, cmap ='viridis', s=50)
plt.title("Aggloremative Clustering: Ward")


clustering = cluster.AgglomerativeClustering(n_clusters=k, linkage='complete')
y_hr = clustering.fit_predict(x)
plt.figure(figsize=(15,5))
plt.subplot(1,2,3)
plt.scatter(X[:,0], X[:,1], c=y_hr, cmap ='viridis', s=50)
plt.title("Aggloremative Clustering: Complete Linkage")

clustering = cluster.AgglomerativeClustering(n_clusters=k, linkage='average')
y_hr = clustering.fit_predict(x)
plt.figure(figsize=(15,5))
plt.subplot(1,2,3)
plt.scatter(X[:,0], X[:,1], c=y_hr, cmap ='viridis', s=50)
plt.title("Aggloremative Clustering: average")

clustering = cluster.AgglomerativeClustering(n_clusters=k, linkage='simgle')
y_hr = clustering.fit_predict(x)
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.scatter(X[:,0], X[:,1], c=y_hr, cmap ='viridis', s=50)
plt.title("Aggloremative Clustering: single")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 12
#      10 y_hr = clustering.fit_predict(x)
#      11 plt.figure(figsize=(15,5))
# ---> 12 plt.subplot(1,2,3)
#      13 plt.scatter(X[:,0], X[:,1], c=y_hr, cmap ='viridis', s=50)
#      14 plt.title("Aggloremative Clustering: Complete Linkage")
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/gridspec.py:598, in SubplotSpec._from_subplot_args(figure, args)
#     596 else:
#     597     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 598         raise ValueError(
#     599             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     600             f"not {num!r}"
#     601         )
#     602     i = j = num
#     603 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 2, not 3

# %%
c =  [(-5,-5), (0,0), (3,4),(10,-5)]
k = 4
n = 200
data = make_blogs(n_samples=m, n_features=2, centers=c, cluster_std=1.5, random_state=50)

X= data[0]

plt.figure(figsize=(15,10))

clustering = cluster.AgglomerativeClustering(n_clusters=k, linkage='ward')
y_km = clustering.fit_predict(X)
plt.subplot(2,2,1)
plt.scatter(X[:,0], X[:,1],c=y_km, cmap = 'viridis', s=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 k = 4
#       3 n = 200
# ----> 4 data = make_blogs(n_samples=m, n_features=2, centers=c, cluster_std=1.5, random_state=50)
#       6 X= data[0]
#       8 plt.figure(figsize=(15,10))
#
# NameError: name 'make_blogs' is not defined

# %%
from scipy.cluster.hierarchy import dendogram, linkage 

plt.figure(figsize=(14,5))

n= 20

data = make_blobs(n_samples = n, n_features =2, centers = c, cluster_std = 2,
                 random_state=42)

x = data[0]
plt.subplot(1,2,1)
plt.scatter(X[:,0], X[:,1], c=data[1], s=50, alpha=0.7, label = 'Posição Verdadeira')

labels = range(0, n)
 for label, x,y in zip(labels, X[:,0], X[:,1]):
        plt.annotate(label, xy=(x,y), xytext=(-3,3), textcoords='offset points', ha= 'right'),
                va='bottom')
            
plt.supbplot(1,2,2)
Z
