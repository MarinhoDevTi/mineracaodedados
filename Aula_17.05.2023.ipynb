# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

random.seed(42)

# %%
data = pd.read_csv('Vehicle.csv', header = (0))

data = data.dropna(axis='rows')

classes = np.array(pd.unique(data[data.columns[-1]]), dtype=str)

feat_names =data.columns

attributes = list(data.columns[0:-2])

data.head(10)
# Out:
#    Comp  Circ  D.Circ  Rad.Ra  Pr.Axis.Ra  Max.L.Ra  Scat.Ra  Elong
# 0    95    48      83     178          72        10      162     42  \
# 1    91    41      84     141          57         9      149     45
# 2   104    50     106     209          66        10      207     32
# 3    93    41      82     159          63         9      144     46
# 4    85    44      70     205         103        52      149     45
# 5   107    57     106     172          50         6      255     26
# 6    97    43      73     173          65         6      153     42
# 7    90    43      66     157          65         9      137     48
# 8    86    34      62     140          61         7      122     54
# 9    93    44      98     197          62        11      183     36
#
#    Pr.Axis.Rect  Max.L.Rect  Sc.Var.Maxis  Sc.Var.maxis  Ra.Gyr  Skew.Maxis
# 0            20         159           176           379     184          70  \
# 1            19         143           170           330     158          72
# 2            23         158           223           635     220          73
# 3            19         143           160           309     127          63
# 4            19         144           241           325     188         127
# 5            28         169           280           957     264          85
# 6            19         143           176           361     172          66
# 7            18         146           162           281     164          67
# 8            17         127           141           223     112          64
# 9            22         146           202           505     152          64
#
#    Skew.maxis  Kurt.maxis  Kurt.Maxis  Holl.Ra Class
# 0           6          16         187      197   van
# 1           9          14         189      199   van
# 2          14           9         188      196  saab
# 3           6          10         199      207   van
# 4           9          11         180      183   bus
# 5           5           9         181      183   bus
# 6          13           1         200      204   bus
# 7           3           3         193      202   van
# 8           2          14         200      208   van
# 9           4          14         195      204  saab

# %%
data = data.to_numpy()

y = data [:,-1]
x = data [:,0:-1]

# %%
from sklearn.model_selection 
import train_test_split

p = 0.2

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = p,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       3 p = 0.2
#       5 x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = p,random_state=42)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.model_selection 
import train_test_split

p = 0.2

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = p,random_state=42)
# Out:
#   Cell In[7], line 1
#     from sklearn.model_selection
#                                  ^
# SyntaxError: invalid syntax

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.17.3 in /home/marinhotech/.local/lib/python3.10/site-packages (from scikit-learn) (1.24.2)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 KB 3.0 MB/s eta 0:00:003.8 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2 scipy-1.10.1 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

p = 0.2

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = p,random_state=42)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier(criterion='gini',random_state = 42)

model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
plt.figure(figsize=(15,10))

tree.plot_tree(model.fit(x_train,y_train),filled=True)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       3 model.fit(x_train,y_train)
#       4 y_pred = model.predict(x_test)
# ----> 6 score = accuracy_score(y_test,y_pred)
#       8 print("Acuracia: ", score)
#
# NameError: name 'accuracy_score' is not defined

# %%
model = RandomForestClassifier(n_estimators= 100, boots)
                    class_weight=
